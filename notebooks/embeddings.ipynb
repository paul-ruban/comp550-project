# %%
from pymagnitude import Magnitude
vecs = Magnitude('http://magnitude.plasticity.ai/word2vec/heavy/GoogleNews-vectors-negative300.magnitude', stream=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_9991/2448824748.py in <module>
# ----> 1 from pymagnitude import Magnitude
#       2 vecs = Magnitude('http://magnitude.plasticity.ai/word2vec/heavy/GoogleNews-vectors-negative300.magnitude', stream=True)
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/pymagnitude/__init__.py in <module>
#      78 sys.path.append(os.path.dirname(__file__) + '/third_party/')
#      79 sys.path.append(os.path.dirname(__file__) + '/third_party_mock/')
# ---> 80 from pymagnitude.third_party.allennlp.commands.elmo import ElmoEmbedder
#      81
#      82 # Import SQLite
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/pymagnitude/third_party/allennlp/commands/__init__.py in <module>
#       6
#       7
# ----> 8 from allennlp.commands.configure import Configure
#       9 from allennlp.commands.elmo import Elmo
#      10 from allennlp.commands.evaluate import Evaluate
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/pymagnitude/third_party/allennlp/commands/__init__.py in <module>
#       6
#       7
# ----> 8 from allennlp.commands.configure import Configure
#       9 from allennlp.commands.elmo import Elmo
#      10 from allennlp.commands.evaluate import Evaluate
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/pymagnitude/third_party/allennlp/commands/configure.py in <module>
#      23
#      24 from allennlp.commands.subcommand import Subcommand
# ---> 25 from allennlp.common.configuration import configure, Config, render_config
#      26
#      27 class Configure(Subcommand):
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/pymagnitude/third_party/allennlp/common/__init__.py in <module>
#       5 from allennlp.common.tee_logger import TeeLogger
#       6 from allennlp.common.tqdm import Tqdm
# ----> 7 from allennlp.common.util import JsonDict
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/pymagnitude/third_party/allennlp/common/util.py in <module>
#      28 import torch
#      29 import numpy
# ---> 30 import spacy
#      31 from spacy.cli.download import download as spacy_download
#      32 from spacy.language import Language as SpacyModelType
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/spacy/__init__.py in <module>
#       9
#      10 # These are imported as part of the API
# ---> 11 from thinc.api import prefer_gpu, require_gpu, require_cpu  # noqa: F401
#      12 from thinc.api import Config
#      13
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/api.py in <module>
#       4 from .loss import CategoricalCrossentropy, L2Distance, CosineDistance
#       5 from .loss import SequenceCategoricalCrossentropy
# ----> 6 from .model import Model, serialize_attr, deserialize_attr
#       7 from .model import set_dropout_rate, change_attr_values, wrap_model_recursive
#       8 from .shims import Shim, PyTorchGradScaler, PyTorchShim, TensorFlowShim, keras_model_fns
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/model.py in <module>
#      11 from .backends import ParamServer, Ops, NumpyOps, CupyOps, get_current_ops
#      12 from .optimizers import Optimizer  # noqa: F401
# ---> 13 from .shims import Shim
#      14 from .util import convert_recursive, is_xp_array, DATA_VALIDATION
#      15 from .util import partial, validate_fwd_input_output
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/shims/__init__.py in <module>
#       1 from .shim import Shim
# ----> 2 from .pytorch import PyTorchShim
#       3 from .pytorch_grad_scaler import PyTorchGradScaler
#       4 from .tensorflow import keras_model_fns, TensorFlowShim, maybe_handshake_model
#       5 from .mxnet import MXNetShim
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/shims/pytorch.py in <module>
#       6 try:
#       7     import torch.autograd
# ----> 8     from torch.cuda import amp
#       9     import torch.optim
#      10     import torch
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/torch/cuda/amp/__init__.py in <module>
# ----> 1 from .autocast_mode import autocast, custom_fwd, custom_bwd  # noqa: F401
#       2 from .grad_scaler import GradScaler  # noqa: F401
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/torch/cuda/amp/autocast_mode.py in <module>
#       9 from torch._six import string_classes
#      10
# ---> 11 class autocast(torch.autocast_mode.autocast):
#      12     r"""
#      13     See :class:`torch.autocast`.
#
# AttributeError: module 'torch' has no attribute 'autocast_mode'
